# %%
! pip install Pillow

# %%
from PIL import Image

# %%
pic = Image.open('../Visuals/appImage.jpeg')
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=278x181 at 0x7FCD77C993A0>
